# %%
# %load mat_to_python.py


# In[3]:


import scipy.io as sio

mat_contents = sio.loadmat('../Theranova070/DATA.5.04_04_2018_10.25.17.915.AM/imuData.mat')
#mat_contents.items()
mat_contents
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Fri Apr 06 13:09:17 2018',
#  '__version__': '1.0',
#  '__globals__': [],
#  'sensorData': array([[(array([[(array([[(array([[100]], dtype=uint8), array(['Hz'], dtype='<U2'), array([[4096]], dtype=uint16), array(['G'], dtype='<U1'), array([[(array([[-2154, -2166, -2161, ...,  -471,  -498,  -590]], dtype=int16), array([[1248, 1252, 1250, ..., -392, -180,   33]], dtype=int16), array([[3280, 3277, 3271, ..., 4164, 4243, 4300]], dtype=int16), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2225e+02, 2.2226e+02,
#          2.2227e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[-0.52587891, -0.52880859, -0.52758789, ..., -0.11499023,
#          -0.12158203, -0.14404297]]), array([[ 0.3046875 ,  0.30566406,  0.30517578, ..., -0.09570312,
#          -0.04394531,  0.00805664]]), array([[0.80078125, 0.80004883, 0.79858398, ..., 1.01660156, 1.03588867,
#          1.04980469]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2225e+02, 2.2226e+02,
#          2.2227e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[(array([[-0.26449627, -0.29354186, -0.3222928 , ..., -0.10306428,
#          -0.09334454, -0.08354605]]), array([[ 0.15288844,  0.16965739,  0.1862597 , ..., -0.00541559,
#          -0.00391565, -0.00263783]]), array([[0.40041032, 0.44443777, 0.48802978, ..., 0.65562357, 0.60389993,
#          0.55108085]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2225e+02, 2.2226e+02,
#          2.2227e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[-0.29321757, -0.35028386, -0.40398582, ..., -0.12882393,
#          -0.11076063, -0.09160331]]), array([[ 0.1698397 ,  0.20283943,  0.23387833, ..., -0.01768701,
#          -0.01722648, -0.01691204]]), array([[0.44421903, 0.53058881, 0.61185897, ..., 0.84652092, 0.75398329,
#          0.65145329]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2225e+02, 2.2226e+02,
#          2.2227e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[-0.31929963, -0.42254639, -0.50423496, ..., -0.11020723,
#          -0.10321869, -0.09327407]]), array([[ 0.18488684,  0.24479433,  0.29215901, ..., -0.07361924,
#          -0.06307008, -0.04401865]]), array([[0.48411823, 0.64030298, 0.76375043, ..., 1.03143104, 0.95921727,
#          0.82221296]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2225e+02, 2.2226e+02,
#          2.2227e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]))]],
#        dtype=[('lpf_2_5Hz', 'O'), ('lpf_5Hz', 'O'), ('lpf_10Hz', 'O')]))]],
#        dtype=[('sampRate', 'O'), ('sampRateUnits', 'O'), ('scale', 'O'), ('scaleUnits', 'O'), ('rawdata', 'O'), ('data', 'O'), ('filterData', 'O')]), array([[(array([[100]], dtype=uint8), array(['Hz'], dtype='<U2'), array([[32.8]]), array(['dps'], dtype='<U3'), array([[(array([[ -18,   11,   -8, ..., 1390, 1631, 1326]], dtype=int16), array([[  -7,   -2,   -5, ...,  970, 1467, 1739]], dtype=int16), array([[ -17,   -7,   -8, ..., -157, -179, -169]], dtype=int16), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2206e+02, 2.2207e+02,
#          2.2208e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[-0.54878049,  0.33536585, -0.24390244, ..., 42.37804878,
#          49.72560976, 40.42682927]]), array([[-0.21341463, -0.06097561, -0.15243902, ..., 29.57317073,
#          44.72560976, 53.01829268]]), array([[-0.51829268, -0.21341463, -0.24390244, ..., -4.78658537,
#          -5.45731707, -5.15243902]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2206e+02, 2.2207e+02,
#          2.2208e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[(array([[-0.10006408, -0.11782331, -0.13652911, ..., 14.68590102,
#          12.63909149, 10.33640062]]), array([[-0.14096084, -0.15257282, -0.1632958 , ...,  2.01101781,
#           1.2597406 ,  0.52079539]]), array([[-0.18989468, -0.21863994, -0.24756891, ..., -7.6080576 ,
#          -7.04759594, -6.28452927]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2206e+02, 2.2207e+02,
#          2.2208e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[-0.1079629 , -0.13558543, -0.16375945, ..., -4.07754378,
#          -2.19738919, -0.02379741]]), array([[-0.09963394, -0.1277494 , -0.15700553, ..., -2.70166319,
#          -3.38871716, -3.49414953]]), array([[-0.16681634, -0.19980342, -0.23328702, ..., -1.6835352 ,
#          -3.3365544 , -4.575454  ]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2206e+02, 2.2207e+02,
#          2.2208e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[-0.10221225, -0.14248878, -0.1835672 , ..., 10.87252319,
#          19.51229212, 23.84992575]]), array([[-0.08147839, -0.14153697, -0.20291525, ..., 28.09574102,
#          35.82627058, 33.9010088 ]]), array([[-0.19020848, -0.24673138, -0.29610089, ..., -3.93399669,
#          -4.25803191, -3.97030182]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2206e+02, 2.2207e+02,
#          2.2208e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]))]],
#        dtype=[('lpf_2_5Hz', 'O'), ('lpf_5Hz', 'O'), ('lpf_10Hz', 'O')]))]],
#        dtype=[('sampRate', 'O'), ('sampRateUnits', 'O'), ('scale', 'O'), ('scaleUnits', 'O'), ('rawdata', 'O'), ('data', 'O'), ('filterData', 'O')]), array([[(array([[10]], dtype=uint8), array(['Hz'], dtype='<U2'), array([[16]], dtype=uint8), array(['uT'], dtype='<U2'), array([[(array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(1, 0), dtype=uint8))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(1, 0), dtype=uint8))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]))]],
#        dtype=[('sampRate', 'O'), ('sampRateUnits', 'O'), ('scale', 'O'), ('scaleUnits', 'O'), ('rawdata', 'O'), ('data', 'O')]), array([[(array([[0.5]]), array(['Hz'], dtype='<U2'), array([[256]], dtype=uint16), array(['meter'], dtype='<U5'), array([[(array([], shape=(0, 0), dtype=uint8), array([], shape=(1, 0), dtype=uint8))]],
#        dtype=[('values', 'O'), ('seconds', 'O')]), array([[(array([], shape=(0, 0), dtype=uint8), array([], shape=(1, 0), dtype=uint8))]],
#        dtype=[('values', 'O'), ('seconds', 'O')]))]],
#        dtype=[('sampRate', 'O'), ('sampRateUnits', 'O'), ('scale', 'O'), ('scaleUnits', 'O'), ('rawdata', 'O'), ('data', 'O')]))]],
#        dtype=[('accel', 'O'), ('gyro', 'O'), ('mag', 'O'), ('baro', 'O')]), array([[(array([[(array([[100]], dtype=uint8), array(['Hz'], dtype='<U2'), array([[8192]], dtype=uint16), array(['G'], dtype='<U1'), array([[(array([[8240, 8314, 8312, ..., 8358, 8390, 8367]], dtype=uint16), array([[-319, -328, -334, ..., -189, -180, -128]], dtype=int16), array([[ 338,  375,  343, ..., -139, -123, -106]], dtype=int16), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 1.1498e+02, 1.1499e+02,
#          1.1500e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[1.00585938, 1.01489258, 1.01464844, ..., 1.02026367, 1.02416992,
#          1.0213623 ]]), array([[-0.03894043, -0.04003906, -0.04077148, ..., -0.02307129,
#          -0.02197266, -0.015625  ]]), array([[ 0.04125977,  0.04577637,  0.04187012, ..., -0.01696777,
#          -0.01501465, -0.01293945]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 1.1498e+02, 1.1499e+02,
#          1.1500e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[(array([[0.50675279, 0.56256263, 0.61782692, ..., 0.67684453, 0.62291128,
#          0.56787259]]), array([[-0.01964401, -0.02168196, -0.02369452, ..., -0.00953139,
#          -0.00742093, -0.00548693]]), array([[ 0.02088545,  0.02301893,  0.02510265, ..., -0.00733345,
#          -0.00742258, -0.00741028]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 1.1498e+02, 1.1499e+02,
#          1.1500e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[0.56151913, 0.670787  , 0.7736553 , ..., 0.87753641, 0.78481288,
#          0.6813893 ]]), array([[-0.02249458, -0.02688719, -0.03096996, ..., -0.0105675 ,
#          -0.00873388, -0.0074518 ]]), array([[ 0.02383208,  0.0282584 ,  0.032339  , ..., -0.01139879,
#          -0.01003054, -0.00841379]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 1.1498e+02, 1.1499e+02,
#          1.1500e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[0.61194622, 0.80936132, 0.9655301 , ..., 1.07691966, 0.97538598,
#          0.81648644]]), array([[-0.02458369, -0.03257916, -0.03869146, ..., -0.01982691,
#          -0.0192953 , -0.01745207]]), array([[ 0.02525307,  0.03316917,  0.03955146, ..., -0.01393831,
#          -0.01427347, -0.01316143]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 1.1498e+02, 1.1499e+02,
#          1.1500e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]))]],
#        dtype=[('lpf_2_5Hz', 'O'), ('lpf_5Hz', 'O'), ('lpf_10Hz', 'O')]))]],
#        dtype=[('sampRate', 'O'), ('sampRateUnits', 'O'), ('scale', 'O'), ('scaleUnits', 'O'), ('rawdata', 'O'), ('data', 'O'), ('filterData', 'O')]), array([[(array([[100]], dtype=uint8), array(['Hz'], dtype='<U2'), array([[131.2]]), array(['dps'], dtype='<U3'), array([[(array([[  921,   825,   803, ...,  -828, -2247,    68]], dtype=int16), array([[-779, -658, -504, ...,  -36,  182,  -27]], dtype=int16), array([[121, 117, 104, ...,  64,  51,  62]], dtype=int16), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2460e+02, 2.2461e+02,
#          2.2462e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[  7.01981707,   6.28810976,   6.12042683, ...,  -6.31097561,
#          -17.12652439,   0.51829268]]), array([[-5.9375    , -5.0152439 , -3.84146341, ..., -0.27439024,
#           1.38719512, -0.20579268]]), array([[0.9222561 , 0.89176829, 0.79268293, ..., 0.48780488, 0.38871951,
#          0.47256098]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2460e+02, 2.2461e+02,
#          2.2462e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[(array([[2.70261227, 2.88972402, 3.06855221, ..., 0.20938903, 1.0783795 ,
#          1.86959308]]), array([[-1.36311037, -1.45350773, -1.54188464, ...,  0.08452427,
#           0.06817774,  0.04900984]]), array([[0.22563783, 0.24567613, 0.26183719, ..., 0.50579922, 0.40301097,
#          0.30126137]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2460e+02, 2.2461e+02,
#          2.2462e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[ 3.74278491,  4.49755302,  5.1686345 , ..., -4.4513293 ,
#          -4.29229065, -3.8491908 ]]), array([[-2.63659617e+00, -2.94165764e+00, -3.16105726e+00, ...,
#          -4.86249049e-02, -2.42563845e-03,  4.21942218e-02]]), array([[ 0.23866008,  0.21720921,  0.1884171 , ...,  0.71384852,
#           0.34165295, -0.00529877]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2460e+02, 2.2461e+02,
#          2.2462e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[ 3.87998377,  4.99342707,  5.83291553, ..., -4.49460242,
#          -4.76177386, -4.39301479]]), array([[-2.71440336, -3.53934925, -4.20413811, ...,  0.07565357,
#           0.09364248,  0.09853972]]), array([[0.63048902, 0.71914479, 0.6822219 , ..., 0.43094823, 0.44488023,
#          0.43926952]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2460e+02, 2.2461e+02,
#          2.2462e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]))]],
#        dtype=[('lpf_2_5Hz', 'O'), ('lpf_5Hz', 'O'), ('lpf_10Hz', 'O')]))]],
#        dtype=[('sampRate', 'O'), ('sampRateUnits', 'O'), ('scale', 'O'), ('scaleUnits', 'O'), ('rawdata', 'O'), ('data', 'O'), ('filterData', 'O')]), array([[(array([[10]], dtype=uint8), array(['Hz'], dtype='<U2'), array([[16]], dtype=uint8), array(['uT'], dtype='<U2'), array([[(array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(1, 0), dtype=uint8))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(1, 0), dtype=uint8))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]))]],
#        dtype=[('sampRate', 'O'), ('sampRateUnits', 'O'), ('scale', 'O'), ('scaleUnits', 'O'), ('rawdata', 'O'), ('data', 'O')]), array([[(array([[0.5]]), array(['Hz'], dtype='<U2'), array([[256]], dtype=uint16), array(['meter'], dtype='<U5'), array([[(array([], shape=(0, 0), dtype=uint8), array([], shape=(1, 0), dtype=uint8))]],
#        dtype=[('values', 'O'), ('seconds', 'O')]), array([[(array([], shape=(0, 0), dtype=uint8), array([], shape=(1, 0), dtype=uint8))]],
#        dtype=[('values', 'O'), ('seconds', 'O')]))]],
#        dtype=[('sampRate', 'O'), ('sampRateUnits', 'O'), ('scale', 'O'), ('scaleUnits', 'O'), ('rawdata', 'O'), ('data', 'O')]))]],
#        dtype=[('accel', 'O'), ('gyro', 'O'), ('mag', 'O'), ('baro', 'O')]), array([[(array([[(array([[100]], dtype=uint8), array(['Hz'], dtype='<U2'), array([[4096]], dtype=uint16), array(['G'], dtype='<U1'), array([[(array([[-3028, -3054, -3058, ..., -2399, -2413, -2415]], dtype=int16), array([[ -505,  -523,  -512, ..., -1681, -1668, -1675]], dtype=int16), array([[2692, 2710, 2699, ..., 2810, 2797, 2795]], dtype=int16), array([[0.000e+00, 1.000e-02, 2.000e-02, ..., 6.872e+01, 6.873e+01,
#          6.874e+01]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[-0.73925781, -0.74560547, -0.74658203, ..., -0.58569336,
#          -0.58911133, -0.58959961]]), array([[-0.12329102, -0.12768555, -0.125     , ..., -0.41040039,
#          -0.40722656, -0.40893555]]), array([[0.65722656, 0.66162109, 0.65893555, ..., 0.68603516, 0.68286133,
#          0.68237305]]), array([[0.000e+00, 1.000e-02, 2.000e-02, ..., 6.872e+01, 6.873e+01,
#          6.874e+01]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[(array([[-0.37213787, -0.4130253 , -0.45350447, ..., -0.39209373,
#          -0.36095971, -0.32908977]]), array([[-0.06287587, -0.0697876 , -0.07662639, ..., -0.27671662,
#          -0.25450968, -0.23179644]]), array([[0.32969189, 0.36593288, 0.40182299, ..., 0.45328736, 0.41752098,
#          0.38095916]]), array([[0.000e+00, 1.000e-02, 2.000e-02, ..., 6.872e+01, 6.873e+01,
#          6.874e+01]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[-0.41330269, -0.49366168, -0.56924825, ..., -0.50266852,
#          -0.44897127, -0.38931643]]), array([[-0.06935085, -0.08298196, -0.09582949, ..., -0.35369944,
#          -0.31528429, -0.27276142]]), array([[0.3656335 , 0.43678293, 0.50377585, ..., 0.58492416, 0.52237485,
#          0.45291768]]), array([[0.000e+00, 1.000e-02, 2.000e-02, ..., 6.872e+01, 6.873e+01,
#          6.874e+01]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[-0.45002859, -0.59558631, -0.71069853, ..., -0.61719564,
#          -0.56061889, -0.47063972]]), array([[-0.07604629, -0.10031528, -0.11935858, ..., -0.43190308,
#          -0.39081328, -0.32700839]]), array([[0.3988029 , 0.52765541, 0.62951456, ..., 0.72011392, 0.6533813 ,
#          0.54755094]]), array([[0.000e+00, 1.000e-02, 2.000e-02, ..., 6.872e+01, 6.873e+01,
#          6.874e+01]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]))]],
#        dtype=[('lpf_2_5Hz', 'O'), ('lpf_5Hz', 'O'), ('lpf_10Hz', 'O')]))]],
#        dtype=[('sampRate', 'O'), ('sampRateUnits', 'O'), ('scale', 'O'), ('scaleUnits', 'O'), ('rawdata', 'O'), ('data', 'O'), ('filterData', 'O')]), array([[(array([[100]], dtype=uint8), array(['Hz'], dtype='<U2'), array([[32.8]]), array(['dps'], dtype='<U3'), array([[(array([[-26, -19, -18, ..., 116, 263, 458]], dtype=int16), array([[ -61,  -66,  -66, ..., -392, -464, -530]], dtype=int16), array([[ -37,  -38,  -45, ..., -267, -330, -371]], dtype=int16), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 1.8014e+02, 1.8015e+02,
#          1.8016e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[-0.79268293, -0.57926829, -0.54878049, ...,  3.53658537,
#           8.01829268, 13.96341463]]), array([[ -1.8597561 ,  -2.01219512,  -2.01219512, ..., -11.95121951,
#          -14.14634146, -16.15853659]]), array([[ -1.12804878,  -1.15853659,  -1.37195122, ...,  -8.1402439 ,
#          -10.06097561, -11.31097561]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 1.8014e+02, 1.8015e+02,
#          1.8016e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[(array([[-0.31760323, -0.36760503, -0.41890097, ...,  8.22483756,
#           7.27382259,  6.39986525]]), array([[ -1.10327165,  -1.25776879,  -1.41268606, ..., -13.83440639,
#          -12.79966143, -11.80449105]]), array([[ -0.90060958,  -1.00173658,  -1.09976923, ..., -11.29240724,
#          -12.14357303, -12.76279117]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 1.8014e+02, 1.8015e+02,
#          1.8016e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[-0.42113113, -0.49183756, -0.55358028, ..., -2.57566075,
#          -2.67907783, -2.19185424]]), array([[-1.04662945, -1.22519357, -1.40208342, ..., -8.38037917,
#          -6.87686879, -5.82558908]]), array([[-0.63483123, -0.8400314 , -1.05680048, ..., -4.04475993,
#          -3.78060662, -3.61486654]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 1.8014e+02, 1.8015e+02,
#          1.8016e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[-0.42182283, -0.54673555, -0.64682158, ...,  9.8339318 ,
#          10.14671461,  8.63740603]]), array([[ -1.23418294,  -1.62074876,  -1.91300012, ..., -14.81034532,
#          -13.4257194 , -11.48615102]]), array([[-0.67166673, -0.8676547 , -1.0536223 , ..., -5.95749931,
#          -8.25391764, -9.39446382]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 1.8014e+02, 1.8015e+02,
#          1.8016e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]))]],
#        dtype=[('lpf_2_5Hz', 'O'), ('lpf_5Hz', 'O'), ('lpf_10Hz', 'O')]))]],
#        dtype=[('sampRate', 'O'), ('sampRateUnits', 'O'), ('scale', 'O'), ('scaleUnits', 'O'), ('rawdata', 'O'), ('data', 'O'), ('filterData', 'O')]), array([[(array([[10]], dtype=uint8), array(['Hz'], dtype='<U2'), array([[16]], dtype=uint8), array(['uT'], dtype='<U2'), array([[(array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(1, 0), dtype=uint8))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(1, 0), dtype=uint8))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]))]],
#        dtype=[('sampRate', 'O'), ('sampRateUnits', 'O'), ('scale', 'O'), ('scaleUnits', 'O'), ('rawdata', 'O'), ('data', 'O')]), array([[(array([[0.5]]), array(['Hz'], dtype='<U2'), array([[256]], dtype=uint16), array(['meter'], dtype='<U5'), array([[(array([], shape=(0, 0), dtype=uint8), array([], shape=(1, 0), dtype=uint8))]],
#        dtype=[('values', 'O'), ('seconds', 'O')]), array([[(array([], shape=(0, 0), dtype=uint8), array([], shape=(1, 0), dtype=uint8))]],
#        dtype=[('values', 'O'), ('seconds', 'O')]))]],
#        dtype=[('sampRate', 'O'), ('sampRateUnits', 'O'), ('scale', 'O'), ('scaleUnits', 'O'), ('rawdata', 'O'), ('data', 'O')]))]],
#        dtype=[('accel', 'O'), ('gyro', 'O'), ('mag', 'O'), ('baro', 'O')]), array([[(array([[(array([[100]], dtype=uint8), array(['Hz'], dtype='<U2'), array([[8192]], dtype=uint16), array(['G'], dtype='<U1'), array([[(array([[8065, 8139, 8132, ..., -576, -570, -570]], dtype=int16), array([[-213, -234, -230, ...,  205,  -72, -775]], dtype=int16), array([[1502, 1499, 1472, ..., 8457, 8460, 8280]], dtype=int16), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2428e+02, 2.2429e+02,
#          2.2430e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[ 0.98449707,  0.99353027,  0.99267578, ..., -0.0703125 ,
#          -0.06958008, -0.06958008]]), array([[-0.02600098, -0.02856445, -0.02807617, ...,  0.02502441,
#          -0.00878906, -0.09460449]]), array([[0.18334961, 0.1829834 , 0.1796875 , ..., 1.03234863, 1.03271484,
#          1.01074219]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2428e+02, 2.2429e+02,
#          2.2430e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[(array([[ 0.49593658,  0.55037909,  0.60427329, ..., -0.05215165,
#          -0.04802859, -0.04383153]]), array([[-0.01076154, -0.01177757, -0.01278133, ..., -0.00375021,
#          -0.00339447, -0.00306833]]), array([[0.0903322 , 0.10023534, 0.11004315, ..., 0.68054269, 0.62601988,
#          0.57038917]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2428e+02, 2.2429e+02,
#          2.2430e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[ 0.5503613 ,  0.65726409,  0.75782347, ..., -0.06885497,
#          -0.0605466 , -0.05148584]]), array([[-0.01553165, -0.01791242, -0.01992032, ..., -0.00668193,
#          -0.00611048, -0.00541772]]), array([[0.10103905, 0.1204856 , 0.13873192, ..., 0.88278386, 0.78893187,
#          0.68442872]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2428e+02, 2.2429e+02,
#          2.2430e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[ 0.5994301 ,  0.79378747,  0.94745238, ..., -0.07367871,
#          -0.06432713, -0.05300476]]), array([[-0.01653884, -0.02173239, -0.02569764, ...,  0.04305303,
#           0.032265  ,  0.00895186]]), array([[0.11018077, 0.14572795, 0.17377893, ..., 1.07814186, 0.9758884 ,
#          0.81776013]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2428e+02, 2.2429e+02,
#          2.2430e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]))]],
#        dtype=[('lpf_2_5Hz', 'O'), ('lpf_5Hz', 'O'), ('lpf_10Hz', 'O')]))]],
#        dtype=[('sampRate', 'O'), ('sampRateUnits', 'O'), ('scale', 'O'), ('scaleUnits', 'O'), ('rawdata', 'O'), ('data', 'O'), ('filterData', 'O')]), array([[(array([[100]], dtype=uint8), array(['Hz'], dtype='<U2'), array([[131.2]]), array(['dps'], dtype='<U3'), array([[(array([[  478,   479,   488, ..., 10937, 11568, 13596]], dtype=int16), array([[  112,    97,    26, ..., -4108, -5025, -5530]], dtype=int16), array([[ 132,  152,  165, ..., 1785, 1897, -423]], dtype=int16), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 1.9848e+02, 1.9849e+02,
#          1.9850e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[  3.64329268,   3.65091463,   3.7195122 , ...,  83.36128049,
#           88.17073171, 103.62804878]]), array([[  0.85365854,   0.73932927,   0.19817073, ..., -31.31097561,
#          -38.30030488, -42.14939024]]), array([[ 1.00609756,  1.15853659,  1.25762195, ..., 13.60518293,
#          14.45884146, -3.22408537]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 1.9848e+02, 1.9849e+02,
#          1.9850e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[(array([[ 1.87373936,  2.11804765,  2.36956061, ..., 19.09297033,
#          20.73935594, 22.05592295]]), array([[-7.92213810e-04, -3.76526031e-02, -7.74502353e-02, ...,
#          -6.49843332e+00, -4.97641136e+00, -3.62650195e+00]]), array([[0.39640826, 0.47913879, 0.56812819, ..., 8.49721565, 7.12578105,
#          5.82355757]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 1.9848e+02, 1.9849e+02,
#          1.9850e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[ 2.12252489,  2.58619189,  3.03861593, ..., 29.77358819,
#          34.52656958, 38.12590113]]), array([[ 0.14135836,  0.11838276,  0.08574451, ..., -3.59750333,
#          -5.51224383, -7.3398587 ]]), array([[ 0.66421952,  0.76397805,  0.85193819, ..., 16.01236826,
#          16.64372271, 16.1962071 ]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 1.9848e+02, 1.9849e+02,
#          1.9850e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[ 2.21870724,  3.05856856,  3.77127413, ..., 84.34436809,
#          88.26860125, 79.72502261]]), array([[  0.38420002,   0.3447214 ,   0.24243095, ..., -17.95302394,
#          -25.05543473, -27.6073171 ]]), array([[ 0.69556906,  0.96238879,  1.17971572, ...,  0.41088633,
#          -4.53466867, -5.80245555]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 1.9848e+02, 1.9849e+02,
#          1.9850e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]))]],
#        dtype=[('lpf_2_5Hz', 'O'), ('lpf_5Hz', 'O'), ('lpf_10Hz', 'O')]))]],
#        dtype=[('sampRate', 'O'), ('sampRateUnits', 'O'), ('scale', 'O'), ('scaleUnits', 'O'), ('rawdata', 'O'), ('data', 'O'), ('filterData', 'O')]), array([[(array([[10]], dtype=uint8), array(['Hz'], dtype='<U2'), array([[16]], dtype=uint8), array(['uT'], dtype='<U2'), array([[(array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(1, 0), dtype=uint8))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(1, 0), dtype=uint8))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]))]],
#        dtype=[('sampRate', 'O'), ('sampRateUnits', 'O'), ('scale', 'O'), ('scaleUnits', 'O'), ('rawdata', 'O'), ('data', 'O')]), array([[(array([[0.5]]), array(['Hz'], dtype='<U2'), array([[256]], dtype=uint16), array(['meter'], dtype='<U5'), array([[(array([], shape=(0, 0), dtype=uint8), array([], shape=(1, 0), dtype=uint8))]],
#        dtype=[('values', 'O'), ('seconds', 'O')]), array([[(array([], shape=(0, 0), dtype=uint8), array([], shape=(1, 0), dtype=uint8))]],
#        dtype=[('values', 'O'), ('seconds', 'O')]))]],
#        dtype=[('sampRate', 'O'), ('sampRateUnits', 'O'), ('scale', 'O'), ('scaleUnits', 'O'), ('rawdata', 'O'), ('data', 'O')]))]],
#        dtype=[('accel', 'O'), ('gyro', 'O'), ('mag', 'O'), ('baro', 'O')]), array([[(array([[(array([[100]], dtype=uint8), array(['Hz'], dtype='<U2'), array([[8192]], dtype=uint16), array(['G'], dtype='<U1'), array([[(array([[7724, 7815, 7769, ..., -685, -726, -713]], dtype=int16), array([[-768, -753, -752, ..., -121, -115, -105]], dtype=int16), array([[2097, 2089, 2090, ..., 8098, 8103, 8077]], dtype=int16), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2679e+02, 2.2680e+02,
#          2.2681e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[ 0.94287109,  0.95397949,  0.94836426, ..., -0.08361816,
#          -0.08862305, -0.08703613]]), array([[-0.09375   , -0.09191895, -0.09179688, ..., -0.01477051,
#          -0.01403809, -0.01281738]]), array([[0.25598145, 0.25500488, 0.25512695, ..., 0.98852539, 0.98913574,
#          0.98596191]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2679e+02, 2.2680e+02,
#          2.2681e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[(array([[ 0.47280006,  0.52487973,  0.57646683, ..., -0.0561943 ,
#          -0.05183262, -0.04738825]]), array([[-0.04433488, -0.04901014, -0.05362591, ..., -0.01032315,
#          -0.00997284, -0.0095557 ]]), array([[0.12922966, 0.14346862, 0.15756469, ..., 0.65280563, 0.60035979,
#          0.54686309]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2679e+02, 2.2680e+02,
#          2.2681e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[ 0.52586875,  0.62772775,  0.72350655, ..., -0.07320206,
#          -0.06554669, -0.05702421]]), array([[-0.05140145, -0.06104197, -0.06995547, ..., -0.01254345,
#          -0.01159887, -0.0104029 ]]), array([[0.14186136, 0.16971457, 0.19601942, ..., 0.84357294, 0.75360841,
#          0.65367512]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2679e+02, 2.2680e+02,
#          2.2681e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[ 0.57328841,  0.75802612,  0.90396681, ..., -0.09054105,
#          -0.08205403, -0.06865504]]), array([[-0.05640921, -0.07394971, -0.08745165, ..., -0.0156378 ,
#          -0.0137175 , -0.01094719]]), array([[0.15370621, 0.20387347, 0.2439695 , ..., 1.03787063, 0.9422274 ,
#          0.79023424]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2679e+02, 2.2680e+02,
#          2.2681e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]))]],
#        dtype=[('lpf_2_5Hz', 'O'), ('lpf_5Hz', 'O'), ('lpf_10Hz', 'O')]))]],
#        dtype=[('sampRate', 'O'), ('sampRateUnits', 'O'), ('scale', 'O'), ('scaleUnits', 'O'), ('rawdata', 'O'), ('data', 'O'), ('filterData', 'O')]), array([[(array([[100]], dtype=uint8), array(['Hz'], dtype='<U2'), array([[131.2]]), array(['dps'], dtype='<U3'), array([[(array([[257, 302, 321, ...,  65,  16, -11]], dtype=int16), array([[ -79, -108, -126, ...,   20,   15,   22]], dtype=int16), array([[133, 119, 122, ...,  84,  71,  64]], dtype=int16), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2659e+02, 2.2660e+02,
#          2.2661e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[ 1.95884146,  2.30182927,  2.44664634, ...,  0.49542683,
#           0.12195122, -0.08384146]]), array([[-0.60213415, -0.82317073, -0.96036585, ...,  0.15243902,
#           0.11432927,  0.16768293]]), array([[1.01371951, 0.9070122 , 0.92987805, ..., 0.6402439 , 0.54115854,
#          0.48780488]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2659e+02, 2.2660e+02,
#          2.2661e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[(array([[ 0.98294991,  1.14983358,  1.32791685, ..., -0.95907459,
#          -1.04881019, -1.10048201]]), array([[-0.36541695, -0.37481042, -0.38071359, ..., -0.39973205,
#          -0.25908784, -0.11083053]]), array([[ 0.47614523,  0.55312599,  0.63378192, ..., -0.10889868,
#          -0.37548061, -0.61697246]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2659e+02, 2.2660e+02,
#          2.2661e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[1.22051325, 1.46665218, 1.70677873, ..., 0.91235854, 0.7011507 ,
#          0.44392291]]), array([[-0.50848945, -0.57149486, -0.61727886, ...,  0.01935436,
#           0.03152413,  0.05266357]]), array([[0.55120944, 0.67349038, 0.79438056, ..., 0.25839082, 0.22698135,
#          0.21160519]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2659e+02, 2.2660e+02,
#          2.2661e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([[1.40098755, 1.86422482, 2.21916399, ..., 0.564852  , 0.32027843,
#          0.10839217]]), array([[-0.47961212, -0.71197311, -0.90881386, ...,  0.10963266,
#           0.14079886,  0.16945459]]), array([[0.56511053, 0.75405897, 0.91901132, ..., 0.76750443, 0.7249968 ,
#          0.57438383]]), array([[0.0000e+00, 1.0000e-02, 2.0000e-02, ..., 2.2659e+02, 2.2660e+02,
#          2.2661e+02]]))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]))]],
#        dtype=[('lpf_2_5Hz', 'O'), ('lpf_5Hz', 'O'), ('lpf_10Hz', 'O')]))]],
#        dtype=[('sampRate', 'O'), ('sampRateUnits', 'O'), ('scale', 'O'), ('scaleUnits', 'O'), ('rawdata', 'O'), ('data', 'O'), ('filterData', 'O')]), array([[(array([[10]], dtype=uint8), array(['Hz'], dtype='<U2'), array([[16]], dtype=uint8), array(['uT'], dtype='<U2'), array([[(array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(1, 0), dtype=uint8))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]), array([[(array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(1, 0), dtype=uint8))]],
#        dtype=[('x', 'O'), ('y', 'O'), ('z', 'O'), ('seconds', 'O')]))]],
#        dtype=[('sampRate', 'O'), ('sampRateUnits', 'O'), ('scale', 'O'), ('scaleUnits', 'O'), ('rawdata', 'O'), ('data', 'O')]), array([[(array([[0.5]]), array(['Hz'], dtype='<U2'), array([[256]], dtype=uint16), array(['meter'], dtype='<U5'), array([[(array([], shape=(0, 0), dtype=uint8), array([], shape=(1, 0), dtype=uint8))]],
#        dtype=[('values', 'O'), ('seconds', 'O')]), array([[(array([], shape=(0, 0), dtype=uint8), array([], shape=(1, 0), dtype=uint8))]],
#        dtype=[('values', 'O'), ('seconds', 'O')]))]],
#        dtype=[('sampRate', 'O'), ('sampRateUnits', 'O'), ('scale', 'O'), ('scaleUnits', 'O'), ('rawdata', 'O'), ('data', 'O')]))]],
#        dtype=[('accel', 'O'), ('gyro', 'O'), ('mag', 'O'), ('baro', 'O')]))]],
#        dtype=[('leftAnkle', 'O'), ('leftHip', 'O'), ('rightAnkle', 'O'), ('rightHip', 'O'), ('tailBone', 'O')])}
